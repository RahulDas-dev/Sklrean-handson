# %%
import os
import sys
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm.notebook import tqdm

# %%
sns.set_theme(style="darkgrid")
sns.set(style='darkgrid', context='notebook', palette='rainbow')
sns.set(rc={'figure.figsize':(4,3)})
pd.set_option("display.max_colwidth", 1000)
random.seed(100)
tqdm.pandas()

# %%
datasource = 'D:/codespace/python/datascience_ml_handson/data/car_evaluation/car.data'

if os.path.isfile(datasource) is False:
    raise FileNotFoundError(f'data souce {datasource} is not Found')
    
dataframe = pd.read_csv(datasource, header=None)  

dataframe.columns = ['buying','maint','doors','persons','lug_boot','safety','class']

print(f'datafame shape {dataframe.shape}')

dataframe.head()
# Out:
# datafame shape (1728, 7)
#   buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   buying    1728 non-null   object
#  1   maint     1728 non-null   object
#  2   doors     1728 non-null   object
#  3   persons   1728 non-null   object
#  4   lug_boot  1728 non-null   object
#  5   safety    1728 non-null   object
#  6   class     1728 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %%
dataframe.isnull().sum()
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safety      0
# class       0
# dtype: int64

# %%
dataframe.duplicated().sum()
# Out:
# 0

# %%
fig, (axs1, axs2,axs3) = plt.subplots(nrows=1, ncols=3, figsize=(18, 4))

sns.countplot(x="buying", data=dataframe, ax=axs1)

sns.countplot(x="maint", data=dataframe, ax=axs2)

sns.countplot(x="doors", data=dataframe, ax=axs3)

plt.show()

# %%
fig, (axs1, axs2,axs3) = plt.subplots(nrows=1, ncols=3, figsize=(18, 4))

sns.countplot(x="persons", data=dataframe, ax=axs1)

sns.countplot(x="lug_boot", data=dataframe, ax=axs2)

sns.countplot(x="safety", data=dataframe, ax=axs3)

plt.show()

# %%
_=sns.countplot(x="class", data=dataframe)

plt.show()

# %%
fig, (axs1, axs2,axs3) = plt.subplots(nrows=1, ncols=3, figsize=(18, 4))

sns.countplot(x="class", data=dataframe, ax=axs1, hue='buying')

sns.countplot(x="class", data=dataframe, ax=axs2, hue='maint')

sns.countplot(x="class", data=dataframe, ax=axs3, hue='doors')

plt.show()

# %%
fig, (axs1, axs2,axs3) = plt.subplots(nrows=1, ncols=3, figsize=(18, 4))

sns.countplot(x="class", data=dataframe, ax=axs1, hue='persons')

sns.countplot(x="class", data=dataframe, ax=axs2, hue='lug_boot')

sns.countplot(x="class", data=dataframe, ax=axs3, hue='safety')

plt.show()
